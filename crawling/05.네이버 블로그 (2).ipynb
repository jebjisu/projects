# %% [markdown]
# 7월 30일

# %%
#selenium 사용을 위한 library import

from selenium import webdriver as wb
from selenium.webdriver.common.by import By #요소 찾기 
from selenium.webdriver.common.keys import Keys #컴터 키보드

# %% [markdown]
# ### 1) 키워드 설정 및 기간 설정하기

# %% [markdown]
# - f-string : 문자열 앞에 f 를 붙이고, 문자열 내부의 중괄호 안에 변수 표현식을 직접 넣어 사용할 수 있는 문자열 포메팅 방식이다

# %%
keyword = ' “음식물%20처리기”%20%2B내돈내산%20-협찬%7C제휴%7C광고%7C체험단%7C쿠폰'

start_date = '20250701'
end_date = '20250715' #기간이 길면 오래걸릴 수 있음 

blog_search_irl = f'https://search.naver.com/search.naver?ssc=tab.blog.all&query={keyword}&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom{start_date}to{end_date}'

# %% [markdown]
# ### 2) 페이지 조회하고, 스크롤 내려보기

# %%
# 1) 브라우저 실행하기 
driver = wb.Chrome()

# %%
# 2) 브라우저 창 최대화 하기 
driver.maximize_window()

# %%
# 3) 페이지 요청하기
url = 'https://search.naver.com/search.naver?ssc=tab.blog.all&query=%E2%80%9C%EC%9D%8C%EC%8B%9D%EB%AC%BC%20%EC%B2%98%EB%A6%AC%EA%B8%B0%E2%80%9D%20%2B%EB%82%B4%EB%8F%88%EB%82%B4%EC%82%B0%20-%ED%98%91%EC%B0%AC%7C%EC%A0%9C%ED%9C%B4%7C%EA%B4%91%EA%B3%A0%7C%EC%B2%B4%ED%97%98%EB%8B%A8%7C%EC%BF%A0%ED%8F%B0&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom20250101to20250716'
driver.get(url)

# %% [markdown]
# - time : 파이썬 내장 모듈, 시간과 다양한 기능을 제공하는 라이브러리 -> time.sleep()
# - 웹페이지가 로딩이 아직 되지 않았거나, 동적 콘텐츠가 생성될 때까지 잠시 기다려야 할 때 사용
#    - 만약 기다리지 않으면 로딩되지 않은 요소를 찾으려고 하다가 오류 발생 가능

# %%
#4) 스크롤 3번 내리기 
import time


for i in range(3):
    body = driver.find_element(By.TAG_NAME, 'body')
    body.send_keys(Keys.END)
    time.sleep(1)

# %% [markdown]
# ### 3. a태그에 있는 href 속성을 찾아서, href_list 리스트에 append 하기

# %%
#1. a태그 찾기 
blog_titles = driver.find_elements(By.CLASS_NAME, 'title_link')
blog_titles
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.113")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.114")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.115")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.116")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.117")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.118")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.119")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.120")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.121")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.122")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.123")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.124")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.125")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.126")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.127")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.128")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.129")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.130")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.131")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.132")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.133")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.134")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.135")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.136")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.137")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.138")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.139")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.140")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.141")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.142")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.143")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.144")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.145")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.146")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.147")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.148")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.149")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.150")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.151")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.152")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.153")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.154")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.155")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.156")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.157")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.158")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.159")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.160")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.161")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.162")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.163")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.164")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.165")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.166")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.167")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.168")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.169")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.170")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.171")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.172")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.173")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.174")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.175")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.176")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.177")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.178")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.179")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.180")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.181")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.182")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.183")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.184")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.185")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.186")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.187")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.188")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.189")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.190")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.191")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.192")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.193")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.194")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.196")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.197")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.198")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.199")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.200")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.201")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.202")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.203")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.204")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.205")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.206")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.207")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.208")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.209")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.211")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.212")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.213")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.215")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.216")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.217")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.218")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.221")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.222")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.223")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.224")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.225")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.226")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.227")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.228")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.229")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.230")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.231")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="522ab6e6e8abfe72a17c1b56cd641356", element="f.3D4A6148AD41C9C97B3B60714317277F.d.D694A01C6A2591A1282C6E8B732D1E9A.e.232")>]

# %%
#2. href를  href_list에 append하기 
href_list = []

#href 추출해야함. 
for i in blog_titles:
    href = i.get_attribute('href')
    href_list.append(href)

# %%
href_list
# Out:
# ['https://blog.naver.com/betty6649/223895650955',
#  'https://blog.naver.com/hozhoni7/223935805837',
#  'https://blog.naver.com/minbr29/223867009834',
#  'https://blog.naver.com/jincrush/223932244462',
#  'https://blog.naver.com/rlarkdmf09/223919669698',
#  'https://blog.naver.com/lbg0610/223825964403',
#  'https://blog.naver.com/3_taste/223934561372',
#  'https://blog.naver.com/hsuni_love/223841996976',
#  'https://blog.naver.com/ie_jima/223865839234',
#  'https://blog.naver.com/cinewriter/223903630339',
#  'https://blog.naver.com/ggggggus/223896977997',
#  'https://blog.naver.com/peacefullife-/223934893631',
#  'https://blog.naver.com/psj2087/223933101982',
#  'https://blog.naver.com/mercidj/223826700262',
#  'https://blog.naver.com/lnk2721/223919163414',
#  'https://blog.naver.com/lovelytrue/223903447512',
#  'https://blog.naver.com/dodookomgod/223931798579',
#  'https://blog.naver.com/hbaroong/223895151245',
#  'https://blog.naver.com/hungry5253/223858633354',
#  'https://blog.naver.com/blue7cok/223919444625',
#  'https://blog.naver.com/sujung_park/223728061903',
#  'https://blog.naver.com/aadkcla/223932419770',
#  'https://blog.naver.com/3_taste/223927375421',
#  'https://blog.naver.com/refurlab/223734441659',
#  'https://blog.naver.com/withoutsoul/223921797059',
#  'https://blog.naver.com/ruinous86/223804688265',
#  'https://blog.naver.com/gary97/223837854114',
#  'https://blog.naver.com/yourim0823/223913759039',
#  'https://blog.naver.com/dbsqosfjq/223815994472',
#  'https://blog.naver.com/jeehyun0719/223899359554',
#  'https://blog.naver.com/marse417/223820850314',
#  'https://blog.naver.com/kkoshooo/223712724066',
#  'https://blog.naver.com/rubinaha/223839127537',
#  'https://blog.naver.com/jejuna17/223800383686',
#  'https://blog.naver.com/mino_ov/223930051658',
#  'https://blog.naver.com/jiyoon_nv/223848595944',
#  'https://blog.naver.com/kizenlove01/223799448141',
#  'https://blog.naver.com/foundersmi/223764097484',
#  'https://blog.naver.com/saebin6/223869702154',
#  'https://blog.naver.com/moon_seo/223867014984',
#  'https://blog.naver.com/syl629/223733425953',
#  'https://blog.naver.com/2025newstart_07/223916983570',
#  'https://blog.naver.com/god2010god/223867752808',
#  'https://blog.naver.com/songhee341/223931994406',
#  'https://blog.naver.com/customize_/223881165468',
#  'https://blog.naver.com/moonylog/223761787156',
#  'https://blog.naver.com/bestfda/223796225857',
#  'https://blog.naver.com/bebrightyou/223871166024',
#  'https://blog.naver.com/green_tea-/223908445681',
#  'https://blog.naver.com/elvanore/223858534783',
#  'https://blog.naver.com/sonya3146/223765315443',
#  'https://blog.naver.com/guy2648/223722339866',
#  'https://blog.naver.com/storyfilm/223862658275',
#  'https://blog.naver.com/eyk6025/223900679126',
#  'https://blog.naver.com/beautifulsun_/223846779493',
#  'https://blog.naver.com/happy_bolbol/223874580531',
#  'https://blog.naver.com/vanillary88/223816794161',
#  'https://blog.naver.com/lovelymj9145/223871243410',
#  'https://blog.naver.com/jhy703011/223795833755',
#  'https://blog.naver.com/sewbaby/223918551797',
#  'https://blog.naver.com/rubinaha/223855507344',
#  'https://blog.naver.com/nudlelog/223886484048',
#  'https://blog.naver.com/qptcjstk6/223801448986',
#  'https://blog.naver.com/hi-gang/223929632060',
#  'https://blog.naver.com/cjh920430/223915861655',
#  'https://blog.naver.com/ah_chu20/223824797337',
#  'https://blog.naver.com/rdg80767/223863368123',
#  'https://blog.naver.com/yeskyl/223812820042',
#  'https://blog.naver.com/askmommy/223925227896',
#  'https://blog.naver.com/heya_onha/223895159915',
#  'https://blog.naver.com/888meekness888/223880285917',
#  'https://blog.naver.com/jj_ciel/223735138621',
#  'https://blog.naver.com/3_taste/223924739576',
#  'https://blog.naver.com/pdbebe/223812274597',
#  'https://blog.naver.com/jini4998/223860424118',
#  'https://blog.naver.com/saltstar79/223872312933',
#  'https://blog.naver.com/dudn2856/223732053833',
#  'https://blog.naver.com/kurohana/223870943371',
#  'https://blog.naver.com/jinhwa3/223782389970',
#  'https://blog.naver.com/ikiss8/223828714151',
#  'https://blog.naver.com/moon6123/223831633055',
#  'https://blog.naver.com/cooing1024/223893809110',
#  'https://blog.naver.com/lucky52happy/223816782012',
#  'https://blog.naver.com/larosee1/223927564426',
#  'https://blog.naver.com/sunae628/223868489866',
#  'https://blog.naver.com/gang_hj_/223889174572',
#  'https://blog.naver.com/miae1216/223841230124',
#  'https://blog.naver.com/yem1217/223812772190',
#  'https://blog.naver.com/young07080/223874343275',
#  'https://blog.naver.com/simplelife8687/223910428510',
#  'https://blog.naver.com/ii__pu/223877378251',
#  'https://blog.naver.com/lovope/223731268224',
#  'https://blog.naver.com/songhee2107/223742914065',
#  'https://blog.naver.com/dudn305/223931415675',
#  'https://blog.naver.com/twinmamy/223830734790',
#  'https://blog.naver.com/coralpinky/223919290555',
#  'https://blog.naver.com/hyesun00701/223910525832',
#  'https://blog.naver.com/akak007v/223810071064',
#  'https://blog.naver.com/bear0sweet/223918533616',
#  'https://blog.naver.com/amazonian3/223873515297',
#  'https://blog.naver.com/ssh4701/223927617011',
#  'https://blog.naver.com/luckystylem/223713997409',
#  'https://blog.naver.com/ddhs21225/223929421431',
#  'https://blog.naver.com/b_bss/223930310221',
#  'https://blog.naver.com/ohbuddhaplzhelpme__/223931543393',
#  'https://blog.naver.com/lr0249/223935419324',
#  'https://blog.naver.com/100sulpost/223933786899',
#  'https://blog.naver.com/nhk2love/223935777363',
#  'https://blog.naver.com/bfly88/223718992857',
#  'https://blog.naver.com/haileykoo922/223914571594',
#  'https://blog.naver.com/heee93su/223915886568',
#  'https://blog.naver.com/11__7/223927410105',
#  'https://blog.naver.com/ddhs21225/223921225518',
#  'https://blog.naver.com/wjdekgml1219/223767671722',
#  'https://blog.naver.com/sady0330/223753853252',
#  'https://blog.naver.com/itdive/223906215982',
#  'https://blog.naver.com/the_ubus/223771940535',
#  'https://blog.naver.com/minju302/223906346624',
#  'https://blog.naver.com/qkq99/223731041358',
#  'https://blog.naver.com/pshwin2/223913554429']

# %% [markdown]
# ### 4. 접속한 블로그 페이지의 내용 수집하기

# %%
#href_list에 있는 첫번째 블로그 페이지를 요청하기 (get요청,href_list 인덱스)
driver.get(href_list[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #href_list에 있는 첫번째 블로그 페이지를 요청하기 (get요청,href_list 인덱스)
# ----> 2 driver.get(href_list[0])
#
# NameError: name 'driver' is not defined

# %%
#iframe으로 전환하기 
driver.switch_to.frame('mainFrame')

# %%
#제목 가져오기 : CLASS_NAME
title = driver.find_element(By.CLASS_NAME, 'se-fs-.se-ff-system')
title.text
# Out:
# '미닉스 음식물처리기 더 플렌더 pro 건조 후기'

# %%
#내용(본문) 가져오기 : CLASS_NAME
content = driver.find_element(By.CLASS_NAME, 'se-main-container')
content.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #내용(본문) 가져오기 : CLASS_NAME
# ----> 2 content = driver.find_element(By.CLASS_NAME, 'se-main-container')
#       3 content.text
#
# NameError: name 'driver' is not defined

# %%
#날짜 가져오기 
date = driver.find_element(By.CSS_SELECTOR, '.se_publishDate.pcol2')
date.text
# Out:
# '2025. 6. 11. 13:16'

# %%
# 수집한 데이터를 담을 리스트
df = []
# 실패한 URL과 오류 사유를 저장할 빈 리스트
failed_url = []  

# 브라우저 실행하기
driver = wb.Chrome()

# href_list 순회하며 데이터 수집하기
for href in href_list:
    try:
        # 1) 페이지 요청하기
        driver.get(href)
        time.sleep(1)  # 페이지 로딩 대기

        # 2) iframe으로 전환하기
        driver.switch_to.frame('mainFrame')

        # 3) 제목 추출하기
        title = driver.find_element(By.CLASS_NAME, 'se-fs-.se-ff-nanummaruburi').text
	
        # 4) 내용 추출하기
        content = driver.find_element(By.CLASS_NAME, 'se-main-container').text

        # 5) 날짜 추출하기
        date = driver.find_element(By.CSS_SELECTOR,'.se_publishDate.pcol2').text

        # 6) df 리스트에 제목, 내용, 날짜, URL 추가하기
        df.append([title, content, date, href])

    except Exception as e:
        # 오류 발생 시 failed_url에 href와 에러 사유 추가하기
        failed_url.append([href, str(e)])

# 7) 드라이버 종료하기
driver.quit()

# 결과 확인
df, failed_url
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 17
#      14 time.sleep(2)  # 페이지 로딩 대기
#      16 # 2) iframe으로 전환하기
# ---> 17 driver.switch_to.frame('mainFrame')
#      19 # 3) 제목 추출하기
#      20 title = driver.find_element(By.CLASS_NAME, 'se-fs-.se-ff-nanummaruburi').text
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\switch_to.py:85, in SwitchTo.frame(self, frame_reference)
#      83 if isinstance(frame_reference, str):
#      84     try:
# ---> 85         frame_reference = self._driver.find_element(By.ID, frame_reference)
#      86     except NoSuchElementException:
#      87         try:
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:922, in WebDriver.find_element(self, by, value)
#     919         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     920     return elements[0]
# --> 922 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:451, in WebDriver.execute(self, driver_command, params)
#     448     elif "sessionId" not in params:
#     449         params["sessionId"] = self.session_id
# --> 451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
#     454     self.error_handler.check_response(response)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~\anaconda3\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~\anaconda3\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\Lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
    #6) df에 제목 , 내용 날짜 href 추가하기 
import pandas as pd
blog_df= pd.DataFrame(df, columns = ['제목', '내용', '날짜', 'URL'])
blog_df
# Out:
#                                                   제목  \
# 0                                보랄음식물처리기 후기 긴급공유합니다
# 1  음식물처리기 추천- 미닉스 더플렌더 프로 내돈내산 솔직후기(+3번째 음쓰기,장단점 리뷰)
# 2                         음식물처리기 린클 3년 사용후기, 지원금신청방법
#
#                                                   내용                  날짜  \
# 0  안녕하세요~\n자취 1년 차!\n혼자 사는 게 뭐 별거겠어~ 했는데\n진짜 집안일,...  2025. 7. 16. 15:10
# 1  나의 3번째 음쓰처리기 미닉스이다.\n첫번째는 beeco, 두번째는 쉘퍼, 세번째 ...  2025. 4. 21. 23:14
# 2  업체로부터 원고료를 지원받아 작성한 후기입니다. 린클은 내돈내산!\n음식물처리기\n...   2025. 4. 8. 22:36
#
#                                               URL
# 0    https://blog.naver.com/hozhoni7/223935805837
# 1  https://blog.naver.com/hsuni_love/223841996976
# 2     https://blog.naver.com/mercidj/223826700262

# %% [markdown]
# ### 5. 내용 전처리하기

# %%
#str.re= place() :문자열에서 특정 문자나 문자열을 다른 문자로 바꿔주는 함수

blog_df['내용']= blog_df['내용'].str.replace('\n', '')
blog_df['내용']
blog_df
# Out:
#                                                   제목  \
# 0                                보랄음식물처리기 후기 긴급공유합니다
# 1  음식물처리기 추천- 미닉스 더플렌더 프로 내돈내산 솔직후기(+3번째 음쓰기,장단점 리뷰)
# 2                         음식물처리기 린클 3년 사용후기, 지원금신청방법
#
#                                                   내용                  날짜  \
# 0  안녕하세요~자취 1년 차!혼자 사는 게 뭐 별거겠어~ 했는데진짜 집안일, 식비, 청...  2025. 7. 16. 15:10
# 1  나의 3번째 음쓰처리기 미닉스이다.첫번째는 beeco, 두번째는 쉘퍼, 세번째 미닉...  2025. 4. 21. 23:14
# 2  업체로부터 원고료를 지원받아 작성한 후기입니다. 린클은 내돈내산!음식물처리기린클3년...   2025. 4. 8. 22:36
#
#                                               URL
# 0    https://blog.naver.com/hozhoni7/223935805837
# 1  https://blog.naver.com/hsuni_love/223841996976
# 2     https://blog.naver.com/mercidj/223826700262

# %%
#날짜 전처리 

blog_df['날짜'] = blog_df['날짜'].str[:-5]
blog_df
# Out:
#                                                   제목  \
# 0                                보랄음식물처리기 후기 긴급공유합니다
# 1  음식물처리기 추천- 미닉스 더플렌더 프로 내돈내산 솔직후기(+3번째 음쓰기,장단점 리뷰)
# 2                         음식물처리기 린클 3년 사용후기, 지원금신청방법
#
#                                                   내용             날짜  \
# 0  안녕하세요~자취 1년 차!혼자 사는 게 뭐 별거겠어~ 했는데진짜 집안일, 식비, 청...  2025. 7. 16.
# 1  나의 3번째 음쓰처리기 미닉스이다.첫번째는 beeco, 두번째는 쉘퍼, 세번째 미닉...  2025. 4. 21.
# 2  업체로부터 원고료를 지원받아 작성한 후기입니다. 린클은 내돈내산!음식물처리기린클3년...   2025. 4. 8.
#
#                                               URL
# 0    https://blog.naver.com/hozhoni7/223935805837
# 1  https://blog.naver.com/hsuni_love/223841996976
# 2     https://blog.naver.com/mercidj/223826700262

# %% [markdown]
# ### 내용 저장하기

# %%
import pandas as pd

blog_df = pd.read_csv(c"./네이버블로그_음식물처리기_start_date20250701-end_date20250715.csv", encoding = 'utf-8-sig', index_col = 0)
# index = 0 : 첫번째 열을 인덱스로 지정하는 방법
blog_df
# Out:
#                                                   제목  \
# 0                                보랄음식물처리기 후기 긴급공유합니다
# 1  음식물처리기 추천- 미닉스 더플렌더 프로 내돈내산 솔직후기(+3번째 음쓰기,장단점 리뷰)
# 2                         음식물처리기 린클 3년 사용후기, 지원금신청방법
#
#                                                   내용             날짜  \
# 0  안녕하세요~자취 1년 차!혼자 사는 게 뭐 별거겠어~ 했는데진짜 집안일, 식비, 청...  2025. 7. 16.
# 1  나의 3번째 음쓰처리기 미닉스이다.첫번째는 beeco, 두번째는 쉘퍼, 세번째 미닉...  2025. 4. 21.
# 2  업체로부터 원고료를 지원받아 작성한 후기입니다. 린클은 내돈내산!음식물처리기린클3년...   2025. 4. 8.
#
#                                               URL
# 0    https://blog.naver.com/hozhoni7/223935805837
# 1  https://blog.naver.com/hsuni_love/223841996976
# 2     https://blog.naver.com/mercidj/223826700262

# %%
# 문자열 포매팅 방식 사용하기 : .format()활용햐보가
#csv 파일로 저장하기 : to_csv
import pandas as pd 

blog_df.to_csv("네이버블로그_음식물처리기_start_date{}-end_date{}.csv".format(start_date,end_date),encoding = 'utf-8-sig')

# %% [markdown]
# ### 7. 워드클라우드 만들기
# 1. 명사추출함수 정의하기
# 2. 명사 리스트 추출(apply)
# 3. 단어별 빈도 계산기 (counter)
# 4. 워드클라우드 그려보기 (WordCloud,plt)

# %%
from konlpy.tag import Okt

# %%
# 1. 명사 추출 함수 정의하기
okt = Okt()

def extract_nouns(text):
    # 1) tag값이 'Noun'이고, len(word) >=2 것들만 반환하기
    # nouns 리스트에 append (조건을 만족하면)
    nouns = []
    
    # pos로 결과 값을 받아보면 : (단어, 품사)
    for word, tag in okt.pos(text):
        if tag == "Noun" and len(word) >= 2:
            nouns.append(word)
    return nouns

# %%
#2. 명사 리스트 추출
blog_df["nouns"] = blog_df["내용"].apply(extract_nouns)
blog_df
# Out:
#                                                   제목  \
# 0                                보랄음식물처리기 후기 긴급공유합니다
# 1  음식물처리기 추천- 미닉스 더플렌더 프로 내돈내산 솔직후기(+3번째 음쓰기,장단점 리뷰)
# 2                         음식물처리기 린클 3년 사용후기, 지원금신청방법
#
#                                                   내용             날짜  \
# 0  안녕하세요~자취 1년 차!혼자 사는 게 뭐 별거겠어~ 했는데진짜 집안일, 식비, 청...  2025. 7. 16.
# 1  나의 3번째 음쓰처리기 미닉스이다.첫번째는 beeco, 두번째는 쉘퍼, 세번째 미닉...  2025. 4. 21.
# 2  업체로부터 원고료를 지원받아 작성한 후기입니다. 린클은 내돈내산!음식물처리기린클3년...   2025. 4. 8.
#
#                                               URL  \
# 0    https://blog.naver.com/hozhoni7/223935805837
# 1  https://blog.naver.com/hsuni_love/223841996976
# 2     https://blog.naver.com/mercidj/223826700262
#
#                                                nouns
# 0  [자취, 혼자, 별거, 진짜, 집안일, 식비, 청소, 쓰레기, 하나, 고비, 서울,...
# 1  [처리기, 미닉스, 두번째, 쉘퍼, 세번, 미닉스, 미닉스, 더플렌더, 프로, 공식...
# 2  [업체, 로부터, 원고료, 지원, 작성, 후기, 음식물, 처리, 기린, 주방, 가전...

# %%
#3. 단어별 빈도 계산하기 (Counter)
from collections import Counter

all_nouns = []

#df["nouns"] 열에 있는 명사들을 하나씩 꺼내서 all_nouns 리스트에 추가할 것임 
for nouns in blog_df["nouns"]:
    all_nouns.extend(nouns)
    #extend : 여러 요소를 한번에 기존 리스트에 추가할 때 사용함 
    #append() 리스트 전체를 하나의 요소로 추가함, extend는 각 요소를 풀어서 하나씩 리스트에 이어 붙임.

# %%
freq_dict = Counter(all_nouns)

# %%
#상이ㅜ 10개 단어 및 빈도 계산하기 
top10 = freq_dict.most_common(10)
top10
# Out:
# [('음식물', 36),
#  ('사용', 22),
#  ('처리기', 18),
#  ('후기', 15),
#  ('냄새', 12),
#  ('정말', 12),
#  ('자취', 10),
#  ('쓰레기', 10),
#  ('주방', 9),
#  ('생각', 8)]

# %%
#불용어 처리 : '음식물', '처리기' 
stopwords = ["음식물","처리기"]

#새로운 필터링된 리스트 생성을 위한 빈 리스트
filtered_nouns = []

for nouns in all_nouns:
    #들어온 명사가 stopwords가 아니라면 , filtered_nouns에 append
    if nouns not in stopwords:
        filtered_nouns.append(nouns)

filtered_nouns
# Out:
# ['자취',
#  '혼자',
#  '별거',
#  '진짜',
#  '집안일',
#  '식비',
#  '청소',
#  '쓰레기',
#  '하나',
#  '고비',
#  '서울',
#  '살이',
#  '직장인',
#  '자취',
#  '실감',
#  '타지',
#  '고생',
#  '엄마',
#  '시골',
#  '요즘',
#  '물가',
#  '외식',
#  '거덜',
#  '점심',
#  '도시락',
#  '저녁',
#  '집밥',
#  '해먹',
#  '루틴',
#  '퇴근',
#  '저녁',
#  '다음',
#  '도시락',
#  '반찬',
#  '혼자',
#  '겨울',
#  '그냥',
#  '여름',
#  '쓰레기',
#  '진짜',
#  '골칫',
#  '덩어리',
#  '주방',
#  '해도',
#  '원룸',
#  '형태',
#  '쓰레기',
#  '봉투',
#  '제일',
#  '사서',
#  '아침',
#  '출근',
#  '집안',
#  '냄새',
#  '기본',
#  '초파리',
#  '난리',
#  '법석',
#  '원룸',
#  '이불',
#  '쓰레기',
#  '냄새',
#  '인스타',
#  '피드',
#  '보랄',
#  '후기',
#  '편집',
#  '때문',
#  '성능',
#  '보이',
#  '디자인',
#  '완전',
#  '자취녀',
#  '친구',
#  '얘기',
#  '자기',
#  '검색',
#  '요즘',
#  '혼자',
#  '사람',
#  '사이',
#  '경우',
#  '대요',
#  '고민',
#  '보랄',
#  '후기',
#  '완전',
#  '정말',
#  '정독',
#  '수준',
#  '장점',
#  '단점',
#  '사용',
#  '후기',
#  '체크',
#  '문제',
#  '생각',
#  '본체',
#  '크기',
#  '자취',
#  '주방',
#  '진짜',
#  '공간',
#  '보랄',
#  '후기',
#  '용량',
#  '라서',
#  '처리량',
#  '자취',
#  '입장',
#  '이틀',
#  '사람',
#  '전기',
#  '세도',
#  '걱정',
#  '무엇',
#  '자리',
#  '차지',
#  '커서',
#  '보랄',
#  '후기',
#  '보기',
#  '회사',
#  '선배',
#  '자취',
#  '다른',
#  '제품',
#  '실물',
#  '선배',
#  '진짜',
#  '타입',
#  '가전',
#  '살때',
#  '항상',
#  '가격',
#  '성능',
#  '후기',
#  '고산',
#  '제품',
#  '보고',
#  '완전',
#  '추천',
#  '언니',
#  '제품',
#  '이바',
#  '젝타',
#  '혼자',
#  '사람',
#  '그날',
#  '바로',
#  '젝타',
#  '공홈',
#  '후기',
#  '연예인',
#  '광고',
#  '그동안',
#  '브랜드',
#  '공홈',
#  '후기',
#  '무려',
#  '심지어',
#  '평균',
#  '평점',
#  '거의',
#  '만점',
#  '수준',
#  '광고',
#  '리뷰',
#  '체험',
#  '단도',
#  '진짜',
#  '후기',
#  '데이',
#  '정도',
#  '반응',
#  '이면',
#  '만하',
#  '가격',
#  '원대',
#  '마음',
#  '마침',
#  '추가',
#  '근무',
#  '수당',
#  '타이밍',
#  '예약',
#  '주문',
#  '배송',
#  '박스',
#  '크기',
#  '실화',
#  '지도',
#  '자취',
#  '주방',
#  '찰떡',
#  '공간',
#  '텐데딱',
#  '자동',
#  '모드',
#  '개꿀',
#  '그냥',
#  '버튼',
#  '수분',
#  '상태',
#  '시간',
#  '스스로',
#  '조절',
#  '처리',
#  '예전',
#  '봉투',
#  '하나',
#  '분류',
#  '스트레스',
#  '그냥',
#  '버튼',
#  '자취',
#  '인생',
#  '원룸',
#  '자취',
#  '제일',
#  '바로',
#  '냄새',
#  '동안',
#  '냄새',
#  '별로',
#  '처리',
#  '뚜껑',
#  '그냥',
#  '가루',
#  '남아',
#  '그거',
#  '그냥',
#  '종량제',
#  '봉투',
#  '넣기',
#  '진짜',
#  '자취',
#  '최고',
#  '소음',
#  '예상',
#  '보랄',
#  '후기',
#  '소음',
#  '기능',
#  '강조',
#  '타가',
#  '한수',
#  '조개',
#  '치킨',
#  '옆집',
#  '전혀',
#  '신경',
#  '드라마',
#  '볼륨',
#  '그대로',
#  '유지',
#  '전혀',
#  '문제',
#  '보랄',
#  '후기',
#  '처음',
#  '보고',
#  '기능',
#  '혼자',
#  '부담',
#  '크기',
#  '가격',
#  '선뜻',
#  '구매',
#  '덕분',
#  '젝타',
#  '제품',
#  '진심',
#  '만족도',
#  '부모님',
#  '음식',
#  '활용',
#  '음식',
#  '이제',
#  '퇴근',
#  '집밥',
#  '해먹',
#  '자취',
#  '주방',
#  '크기',
#  '설치',
#  '기세',
#  '걱정',
#  '혼자',
#  '직장인',
#  '라면',
#  '정말',
#  '추천',
#  '젝타',
#  '덕분',
#  '쓰레기',
#  '걱정',
#  '안녕',
#  '집밥',
#  '라이프',
#  '날개',
#  '기분',
#  '수정',
#  '생각',
#  '쪽지',
#  '문의',
#  '아래',
#  '링크',
#  '확인',
#  '젝타',
#  '젝타',
#  '압도',
#  '모터',
#  '성능',
#  '분쇄',
#  '모터',
#  '중날',
#  '커터',
#  '분쇄',
#  '퍼포먼스',
#  '도의',
#  '고온',
#  '건조',
#  '기술',
#  '볼륨',
#  '감소',
#  '카톡',
#  '회원',
#  '입시',
#  '즉시',
#  '미닉스',
#  '두번째',
#  '쉘퍼',
#  '세번',
#  '미닉스',
#  '미닉스',
#  '더플렌더',
#  '프로',
#  '공식',
#  '런칭',
#  '바로',
#  '라이브',
#  '구매',
#  '제품',
#  '잔고',
#  '소음',
#  '이슈',
#  '약간',
#  '불만족',
#  '부분',
#  '생각',
#  '구매',
#  '가장',
#  '동기',
#  '아이',
#  '예정',
#  '제품',
#  '구매',
#  '구매',
#  '첫날',
#  '최저',
#  '가라',
#  '홍보',
#  '제일',
#  '최저',
#  '다른',
#  '플랫폼',
#  '사은',
#  '탈취',
#  '그닥',
#  '쓸모',
#  '차라리',
#  '필터',
#  '주지',
#  '색상',
#  '레이지',
#  '아이보리',
#  '그레이',
#  '느낌',
#  '인테리어',
#  '사용설명서',
#  '보기',
#  '추천',
#  '정말',
#  '이용',
#  '꿀팁',
#  '싱크대',
#  '두기',
#  '사이즈',
#  '컴팩트',
#  '요즘',
#  '주방',
#  '질감',
#  '찰떡',
#  '색감',
#  '필터',
#  '부분',
#  '필터',
#  '그대로',
#  '비닐',
#  '바닥',
#  '스티커',
#  '다시',
#  '두기',
#  '역시',
#  '바닥',
#  '테이프',
#  '제거',
#  '다시',
#  '넣기',
#  '구성',
#  '얘기',
#  '생각',
#  '조작',
#  '버튼',
#  '오프',
#  '오토',
#  '모드',
#  '보관',
#  '모드',
#  '처리',
#  '모드',
#  '오토',
#  '버튼',
#  '뚜껑',
#  '거의',
#  '찰때',
#  '보관',
#  '모드',
#  '유지',
#  '만약',
#  '그냥',
#  '수동',
#  '진행',
#  '걱정',
#  '분쇄',
#  '입자',
#  '살짝',
#  '빠삭빠삭하',
#  '분쇄기',
#  '능이',
#  '오히려',
#  '가루',
#  '날림',
#  '부피',
#  '이제',
#  '장점',
#  '단점',
#  '정리',
#  '타임',
#  '소음',
#  '작동',
#  '소리',
#  '거의',
#  '정도',
#  '제품',
#  '제일',
#  '자동',
#  '보관',
#  '모드',
#  '보관',
#  '분쇄',
#  '무취',
#  '보관',
#  '모드',
#  '작동',
#  '냄새',
#  '보관',
#  '가능',
#  '제일',
#  '무취였음',
#  '구성',
#  '사용',
#  '기준',
#  '구성',
#  '흠집',
#  '현상',
#  '디자인',
#  '색상',
#  '디자인',
#  '제한',
#  '뿌리',
#  '피해',
#  '용량',
#  '리터',
#  '가구',
#  '대가족',
#  '경우',
#  '수도',
#  '필터',
#  '교체',
#  '비용',
#  '평균',
#  '개월',
#  '주기',
#  '조금',
#  '사은',
#  '탈취',
#  '미닉스',
#  '프로',
#  '미니어처',
#  '디자인',
#  '크기',
#  '사이즈',
#  '동봉',
#  '탈취',
#  '고체',
#  '우리',
#  '신발장',
#  '냄새',
#  '경우',
#  '건조',
#  '세척',
#  '모드',
#  '진행',
#  '절반',
#  '커피',
#  '찌꺼기',
#  '녹차',
#  '티백',
#  '필터',
#  '케이스',
#  '세척',
#  '활성탄',
#  '세척',
#  '완전',
#  '건조',
#  '활성탄',
#  '필터',
#  '구조',
#  '유지',
#  '교체',
#  '투입',
#  '불가',
#  '뿌리',
#  '옥수수',
#  '과일',
#  '줄기',
#  '꼭지',
#  '왕겨',
#  '어패류',
#  '계란',
#  '껍질',
#  '주의',
#  '사항',
#  '섬유질',
#  '분류',
#  '체류',
#  '다른',
#  '혼합',
#  '넣기',
#  '미닉스',
#  '조작',
#  '방법',
#  '중량',
#  '초기',
#  '이상',
#  '건조',
#  '분리',
#  '음량조절',
#  '버튼',
#  '단계',
#  '조절',
#  '가능',
#  '뚜껑',
#  '분리',
#  '세척',
#  '가능',
#  '부분',
#  '아래쪽',
#  '부분',
#  '구매',
#  '제품',
#  '인증',
#  '할인',
#  '쿠폰',
#  '연장',
#  '할인',
#  '쿠폰',
#  '생일',
#  '적립금',
#  '평생',
#  '무료',
#  '배송',
#  '혜택',
#  '리뷰',
#  '적립금',
#  '이유',
#  '개월',
#  '사용',
#  '추천',
#  '업체',
#  '로부터',
#  '원고료',
#  '지원',
#  '작성',
#  '후기',
#  '처리',
#  '기린',
#  '주방',
#  '가전',
#  '하나',
#  '가바',
#  '부터',
#  '사용',
#  '지금',
#  '주택',
#  '사용',
#  '미생물',
#  '자연',
#  '점도',
#  '정말',
#  '마음',
#  '지금',
#  '사용',
#  '후기',
#  '지자체',
#  '원금',
#  '방법',
#  '지역',
#  '해당',
#  '해당',
#  '지역',
#  '보조금',
#  '지원',
#  '사면',
#  '알뜰살뜰',
#  '최대',
#  '지원',
#  '확인',
#  '구매',
#  '아래',
#  '링크',
#  '지원',
#  '사업',
#  '대상',
#  '지역',
#  '신청',
#  '방법',
#  '참고',
#  '브랜드',
#  '스토어',
#  '브랜드',
#  '스토어',
#  '공식',
#  '온라인',
#  '사용',
#  '유저',
#  '미생물',
#  '사용',
#  '스테인레스',
#  '쓰레기통',
#  '사용',
#  '아파트',
#  '살때',
#  '때문',
#  '조금',
#  '주택',
#  '쓰레기',
#  '봉투',
#  '용해',
#  '여간',
#  '고양이',
#  '기도',
#  '마당',
#  '집앞',
#  '기도',
#  '가족',
#  '저희',
#  '며칠',
#  '집안',
#  '자체',
#  '기도',
#  '냄새',
#  '나기',
#  '여름',
#  '더욱',
#  '때문',
#  '스트레스',
#  '고민',
#  '해방',
#  '바로',
#  '사용',
#  '후음',
#  '식물',
#  '주방',
#  '한결',
#  '보이',
#  '사용',
#  '미생물',
#  '쓰레기',
#  '주니',
#  '정말',
#  '기도',
#  '환경',
#  '생각',
#  '기분',
#  '미생물',
#  '생각',
#  '뭔가',
#  '엽기',
#  '우리',
#  '딸도',
#  '음식',
#  '주기도',
#  '과정',
#  '미생물',
#  '대해',
#  '이야기',
#  '사실',
#  '음식',
#  '저희',
#  '거의',
#  '시세',
#  '해먹',
#  '부부',
#  '아이',
#  '명의',
#  '가족',
#  '쓰레기',
#  '크기',
#  '프라임',
#  '사용',
#  '덕분',
#  '주방',
#  '관리',
#  '냄새',
#  '용법',
#  '용법',
#  '정말',
#  '전원',
#  '코드',
#  '미생물',
#  '준비',
#  '완료',
#  '사용',
#  '방법',
#  '아주',
#  '직관',
#  '전원',
#  '탈취',
#  '버튼',
#  '미생물',
#  '물기',
#  '관리',
#  '냄새',
#  '살짝',
#  '탈취',
#  '부분',
#  '대면',
#  '작동',
#  '어르신',
#  '사용',
#  '주택',
#  '사시',
#  '부모님',
#  '선물',
#  '정말',
#  '가까이',
#  '가면',
#  '센서',
#  '자동',
#  '리기',
#  '때문',
#  '버튼',
#  '화이트',
#  '디자인',
#  '화이트',
#  '우드',
#  '주방',
#  '찰떡',
#  '성능',
#  '가전',
#  '디자인',
#  '생각',
#  '무조건',
#  '냉장고',
#  '덕분',
#  '관리',
#  '관리',
#  '방법',
#  '저희',
#  '매일',
#  '쓰레기',
#  '금세',
#  '항상',
#  '사진',
#  '살짝',
#  '사용',
#  '정말',
#  '응대',
#  '성심',
#  '성의껏',
#  '상담',
#  '수리',
#  '과정',
#  '정말',
#  '포장',
#  '박스',
#  '포장',
#  '부분',
#  '서비스',
#  '정말',
#  '교체',
#  '성능',
#  '디자인',
#  '고객',
#  '응대',
#  '정말',
#  '정말',
#  '생각',
#  '마음',
#  '동안',
#  '사용',
#  '한번',
#  '교체',
#  '유지비',
#  '용이',
#  '별로',
#  '사용',
#  '관리',
#  '포함',
#  '일정량',
#  '상태',
#  '볼때',
#  '자주',
#  '확인',
#  '편이',
#  '주택',
#  '살기',
#  '때문',
#  '친환경',
#  '방식',
#  '마음',
#  '부산물',
#  '경우',
#  '미생물',
#  '비율',
#  '숙성',
#  '퇴비',
#  '사용',
#  '때문',
#  '조금',
#  '만들기',
#  '위해',
#  '설거지',
#  '양념',
#  '모두',
#  '사용',
#  '관리',
#  '도움',
#  '관해',
#  '냄새',
#  '걱정',
#  '냄새',
#  '사람',
#  '냄새',
#  '살짝',
#  '경우',
#  '유지',
#  '결과',
#  '쓰레기',
#  '처리',
#  '해방',
#  '신분',
#  '지자체',
#  '원금',
#  '확인',
#  '사용',
#  '사용',
#  '후기',
#  '재생',
#  '접기',
#  '사용',
#  '후기']

# %%
freq_dict = Counter(filtered_nouns)

top10 = freq_dict.most_common(10)
top10
# Out:
# [('사용', 22),
#  ('후기', 15),
#  ('냄새', 12),
#  ('정말', 12),
#  ('자취', 10),
#  ('쓰레기', 10),
#  ('주방', 9),
#  ('생각', 8),
#  ('제품', 8),
#  ('모드', 8)]

# %%
#워드클라우드 그리기 위한 library import 하기 
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
#워드클라우드 객체 만들기
wc = WordCloud(
    font_path ='C:/Windows/Fonts/malgunbd.ttf',
    background_color = 'white',
    width = 800,
    height = 600
).generate_from_frequencies(dict(freq_dict))
#generate_from_frequencies() :단어-빈도 딕셔너리를 바탕으로 워드클라우드를 생성해주는 함수
#freq_dict :(단어, 빈도) 쌍으로 있는 Counter 객체 -> 딕셔너리 형태로 변환이 필요하다

# %%
#워드클라우드 이미지 표시하기
plt.figure(figsize = (10,8))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()
