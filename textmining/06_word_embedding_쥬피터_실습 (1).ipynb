# %% [markdown]
# ## * 데이터 준비

# %%
import nltk
nltk.download("punkt")
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\152\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\152\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\152\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\152\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\152\Downloads\영어 크롤링.csv", encoding="utf-8")
df
# Out:
#                     Date                      Name  Score  \
# 0       January 26, 2020              Bernard Reis      1
# 1       January 18, 2020              Gordon Inman      2
# 2       January 18, 2020                   MrDurma      4
# 3       January 26, 2020                  K Kostas      3
# 4       January 17, 2020                Greg Evans      3
# ...                  ...                       ...    ...
# 7145   December 31, 2019  Mr Darryl Maurice Friend      5
# 7146    January 12, 2020                luis arias      5
# 7147  September 24, 2017           Tobiloba Bakare      5
# 7148    October 13, 2017             A Google user      5
# 7149      April 14, 2018              vaka vardhan      5
#
#                                                  Review  like
# 0     Completely frustrating experience. Paid extra ...     7
# 1     Some good features, but this app isn't very sm...     8
# 2     This app works perfectly, it allowed us to dow...     2
# 3     Good but not great for an app by LG. Not the m...     1
# 4     App is useful but limited and requires some up...     1
# ...                                                 ...   ...
# 7145                                          Wonderful     0
# 7146                                          Wonderful     0
# 7147                                    Awesome 🌟 🌟 🌟 🌟     0
# 7148                                     Good Good Good     0
# 7149                                              🙌🙏🙏😍l     0
#
# [7150 rows x 5 columns]

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
#stopwords

# %%
def pos_tagging(string):
    string = string.lower() #문자를 소문자로 전체로 변환 -> string 담아줌
    #형태소 분리하기 
    string = nltk.word_tokenize(string)
    string = nltk.pos_tag(string)
    result = [word for word, tag in string if tag in {"NN","NNS","NNP","NNPS"} if word not in stopwords]
    return result

# %%
#nltk tagset 보기 
nltk.download('tagsets')

nltk.help.upenn_tagset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 download('averaged_perceptron_tagger')  # pos_tag용
#       2 nltk.download('punkt')  # word_tokenize용
#       3 #nltk tagset 보기
#
# NameError: name 'download' is not defined

# %%
from tqdm import tqdm #프로세스바

# %%
tagged_pos_document = []
for i in tqdm(df['Review']):
    tagged_pos_document.append(pos_tagging(i))

# %% [markdown]
# ## 1. Word2Vec
# - vector_size=100 → 단어 벡터의 차원 수 (일반적으로 논문에서 100~300사용)
# - window=2 → 중심 단어 기준으로 앞뒤 2개 단어를 컨텍스트로 사용
# - min_count=1 → 최소 1번 이상 등장한 단어만 학습
# - sg → 학습방식 (0이면 CBOW, 1이면 Skip-gram)

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\152\anaconda3\envs\textmining\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\152\anaconda3\envs\textmining\lib\site-packages (from gensim) (1.26.4)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\152\anaconda3\envs\textmining\lib\site-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\users\152\anaconda3\envs\textmining\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ------- -------------------------------- 8.4/46.2 MB 52.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 20.4/46.2 MB 53.8 MB/s eta 0:00:01
#    -------------------------- ------------- 30.9/46.2 MB 53.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 32.5/46.2 MB 40.5 MB/s eta 0:00:01
#    --------------------------------- ------ 38.5/46.2 MB 37.7 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 38.1 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 35.9 MB/s  0:00:01
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed scipy-1.13.1

# %%
from gensim.models import Word2Vec

# %%
from gensim.models import Word2Vec

w2v_model = Word2Vec(tagged_pos_document, vector_size=100, window=2, min_count=1, sg=0)

w2v_model.wv.key_to_index.keys()

w2v_model.wv["app"]

w2v_model.wv.most_similar("app", topn=20)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from gensim.models import Word2Vec
#       3 w2v_model = Word2Vec(tagged_pos_document, vector_size=100, window=2, min_count=1, sg=0)
#       5 w2v_model.wv.key_to_index.keys()
#
# ModuleNotFoundError: No module named 'gensim'

# %%
w2v_model.wv.key_to

# %% [markdown]
# ## 2. Doc2Vec
# - vector_size: 문서 벡터의 차원
# - alpha : 모델 학습시 초기학습률
# - min_alpha: alpha가 이 값 이하로 감소하지 않도록 제한하는 값
# - window: 주변 단어를 고려하는 범위
# - min_count: 단어 최소 등장 횟수
# - epochs: 학습 반복 횟수
# - dm: 1은 PV-DM, 0은 PV-DBOW

# %%
from gensim.models.doc2vec import Doc2Vex
from gensim.models.doc2Vec import TaggedDocument
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from gensim.models.doc2vec import Doc2Vex
#       2 from gensim.models.doc2Vec import TaggedDocument
#
# ModuleNotFoundError: No module named 'gensim'

# %% [markdown]
# ## 3. FastText
